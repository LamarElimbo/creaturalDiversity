# %%
# Set up data collection foundation

CREATURE_NAME=[]
CREATURE_CAT=[]
SEASON_EP=[]
SHOW_NAME=[]

TABLE_COLUMNS = ['creature_name', 'creature_cat', 'season_ep', 'show_name']

DATABASE = {'creature_name':CREATURE_NAME, 'creature_cat':CREATURE_CAT, 'season_ep':SEASON_EP, 'show_name':SHOW_NAME}

VD_URL = 'http://vampirediaries.wikia.com/wiki/Category:Species'

# %%
# Libraries

from bs4 import BeautifulSoup as soup
import pandas as pd
import re
from urllib import request

# %%
# Convert html to a more user friendly format

def soupTheLink(url):
    html = request.urlopen(url).read().decode('utf8')
    return soup(html, 'lxml')

# %%
# Scrape a list of links of the creature categories

def collectCatLinks(url):
    categoryLinks = []
    
    souped = soupTheLink(url)
    subcategories = souped.find(id='mw-subcategories')
    gallery = subcategories.find(class_='category-gallery-room1')
    for listItem in gallery.find_all(class_='category-gallery-item'):
        link = listItem.find('a', href = True)
        try:
            fullLink = link['href']
            categoryLinks.append(fullLink)
        except TypeError:
            pass
    return categoryLinks

# %%
def findNumCreaturePages(url):
    souped = soupTheLink(url)
    pages = 0
    for subcategories in souped.find_all(id='mw-subcategories'):
        for pagination in subcategories.find_all(class_='wikia-paginator'):
            for listItem in pagination.find_all('li'):
                pages += 1
    return pages

# %%
# Jump into the list of links to the creatures based on the categories

def intoCategoryLinks(catLinks):
    currentCategory=''
    
    for mainLink in catLinks:
        currentCategory = mainLink
        print('current category: ', currentCategory)
        numPages = findNumCreaturePages(mainLink) - 1
        if numPages == 0:
            pass
        else:
            for i in range(1,numPages):
                url = mainLink  + '?page=' + str(i)
                collectCreatureLinks(url, currentCategory)

# %%
# Find the number of pages in each category

def findNumCreaturePages(url):
    souped = soupTheLink(url)
    pages = 0
    subcategories = souped.find(id='mw-pages')
    pagination = subcategories.find(class_='wikia-paginator')
    try:
        for listItem in pagination.find_all('li'):
            pages += 1
    except AttributeError:
        pass
    return pages

# %%
# Compile a list of links to each individual creature

def collectCreatureLinks(url, currentCat):
    souped = soupTheLink(url)
    subcategories = souped.find(id='mw-pages')
    for listItem in subcategories.find_all(class_='category-gallery-item'):
        link = listItem.find('a', href = True)
        try:
            fullLink = link['href']
            findCategory(currentCat)
            intoCreatureLinks(fullLink)
        except TypeError:
            pass

# %%
# Import creature category to database

def findCategory(url):
    category = str(url[46:])
    DATABASE['creature_cat'].append(category)

# %%
# Import the rest of the data to the database

def intoCreatureLinks(creatureUrl):
    print('starting intoCreatureLinks: ', creatureUrl)
    souped = soupTheLink(creatureUrl)

        #collect creature name
        name = creatureUrl[37:]
        DATABASE['creature_name'].append(name)

        #collect show name
        DATABASE['show_name'].append('Vampire Diaries')
    
    try:
        #collect season appearances
        currentSeason = 0
        seasonLink = ''
        body = souped.find(id='mw-content-text')
        print('found body: ', body != None)
        SEASON_EP=[]

        heading = body.find(id='Appearances')
        print('found heading: ', heading != None)

        if heading == None:
            pass
        else:
            parent = heading.find_parent()
            tables = parent.find_next_sibling('table')
            print('found tables: ', tables != None)

            checkSeasons = tables.find('dl')

            if checkSeasons == None:
                for seasons in tables.find_all('b'):
                    single=[]
                    seasonDegree = 0
                    print('found a b season')
                    seasonLink = seasons.find('a', href=True)
                    season = seasons.get_text()
                    season = season[7:]
                    print('season ', season)
                    single.append(season)
                    parent = seasons.find_parent()
                    print('found parent: ', parent != None)
                    episodes = parent.find_next_sibling('ul')
                    for episode in episodes.find_all('li'):
                        print('found an episode')
                        seasonDegree += 1
                    single.append(seasonDegree)
                    SEASON_EP.append(single)
            else:
                for seasons in tables.find_all('dl'):
                    single=[]
                    seasonDegree = 0
                    print('found a dl season')
                    seasonLink = seasons.find('a', href=True)
                    season = seasons.get_text()
                    season = season[7:]
                    print('season ', season)
                    single.append(season)
                    episodes = seasons.find_next_sibling('ul')
                    for episode in episodes.find_all('li'):
                        print('found an episode')
                        seasonDegree += 1
                    single.append(seasonDegree)
                    SEASON_EP.append(single)


        if SEASON_EP == []:
            DATABASE['season_ep'].append('None')   
        else:
            DATABASE['season_ep'].extend([SEASON_EP])

    except AttributeError:
        DATABASE['season_ep'].append('None')

# %%
# Run program

numPages = findNumCreaturePages(VD_URL) - 1
for i in range(1,numPages):
    url = VD_URL + '?page=' + str(i)
    print('mainLink: ', url)
    

    categoryLinks = collectCatLinks(url)
    intoCategoryLinks(categoryLinks)
# Out:
# mainLink:  http://vampirediaries.wikia.com/wiki/Category:Species?page=1
# current category:  http://vampirediaries.wikia.com/wiki/Category:Supernatural
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Niklaus_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Six
# found parent:  True
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Elena_Gilbert
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  r Truth
# found parent:  True
# found an episode
# found a b season
# season  1
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  2
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  3
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  4
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  5
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  6
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  7
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Damon_Salvatore
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  r Truth
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  One
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Six
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Eight
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  ginals Season Three
# found parent:  True
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Katerina_Petrova
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Stefan_Salvatore
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  r Truth
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  One
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Six
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Eight
# found parent:  True
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Kol_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# found a dl season
# season  3
#
# found an episode
# found an episode
# found an episode
# found an episode
# found a dl season
# season  4
#
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a dl season
# season  5
#
# found an episode
# found a dl season
# season  7
#
# found an episode
# found a dl season
# season  One
#
# found an episode
# found an episode
# found a dl season
# season  Two
#
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a dl season
# season  Three
#
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Caroline_Forbes
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  One
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Six
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Eight
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  ginals Season One
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  ginals Season Three
# found parent:  True
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Bonnie_Bennett
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  r Truth
# found parent:  True
# found an episode
# found a b season
# season  One
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Six
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Eight
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  ginals Season One
# found parent:  True
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Hope_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Jeremy_Gilbert
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Elijah_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Freya_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  son Two
# found parent:  True
# found an episode
# found a b season
# season  son Three
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  son Seven
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Davina_Claire
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Silas
# found body:  True
# found heading:  True
# found tables:  True
# found a dl season
# season  Four
#
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a dl season
# season  Five
#
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a dl season
# season  Six
#
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Hayley_Marshall-Kenner
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Rebekah_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Tyler_Lockwood
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  One
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Six
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Eight
# found parent:  True
# found an episode
# found a b season
# season  ginals Season One
# found parent:  True
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Malachai_Parker
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  Six
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Lorenzo_St._John
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  Five
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Six
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  Eight
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  ginals Season Three
# found parent:  True
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Camille_O%27Connell
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Marcel_Gerard
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  pire Diaries Season Four
# found parent:  True
# found an episode
# found a b season
# season  ginals Season One
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Season Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Season Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Season Four
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Finn_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  pire Diaries Third Season
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals First Season
# found parent:  True
# found an episode
# found an episode
# found a b season
# season  ginals Second Season
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Third Season
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Lillian_Salvatore
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Esther_Mikaelson
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Lucien_Castle
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Rayna_Cruz
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  Seven
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Season Three
# found parent:  True
# found an episode
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Josette_Laughlin
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Doppelg%C3%A4nger
# found body:  True
# found heading:  True
# found tables:  True
# starting intoCreatureLinks:  http://vampirediaries.wikia.com/wiki/Mikael
# found body:  True
# found heading:  True
# found tables:  True
# found a b season
# season  pire Diaries Season Three
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Season One
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Season Two
# found parent:  True
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found an episode
# found a b season
# season  ginals Season Three
# found parent:  True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-1f38f9931a7d> in <module>()
#       8
#       9     categoryLinks = collectCatLinks(url)
# ---> 10     intoCategoryLinks(categoryLinks)
#
# <ipython-input-20-6a5b0923beba> in intoCategoryLinks(catLinks)
#      13             for i in range(1,numPages):
#      14                 url = mainLink  + '?page=' + str(i)
# ---> 15                 collectCreatureLinks(url, currentCategory)
#
# <ipython-input-22-914d98918b56> in collectCreatureLinks(url, currentCat)
#       9             fullLink = link['href']
#      10             findCategory(currentCat)
# ---> 11             intoCreatureLinks(fullLink)
#      12         except TypeError:
#      13             pass
#
# <ipython-input-126-92bc1fdea1f6> in intoCreatureLinks(creatureUrl)
#      44                 print('found parent: ', parent != None)
#      45                 episodes = parent.find_next_sibling('ul')
# ---> 46                 for episode in episodes.find_all('li'):
#      47                     print('found an episode')
#      48                     seasonDegree += 1
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
print('1: ', len(CREATURE_NAME), '2: ', len(CREATURE_CAT), '3: ', len(SEASON_EP), '4: ', len(SHOW_NAME), )
# Out:
# 1:  6 2:  6 3:  5 4:  6

# %%
print(DATABASE)
# Out:
# {'creature_cat': ['Supernatural', 'Supernatural', 'Supernatural', 'Supernatural', 'Supernatural', 'Supernatural'], 'season_ep': [[['Two', 6], ['Three', 18], ['Four', 19], ['Five', 7], ['Six', 1], ['Seven', 3]], [['r Truth', 1], ['1', 22], ['2', 22], ['3', 22], ['4', 23], ['5', 22], ['6', 22], ['7', 18]], [['r Truth', 2], ['One', 22], ['Two', 22], ['Three', 22], ['Four', 23], ['Five', 22], ['Six', 22], ['Seven', 22], ['Eight', 2], ['ginals Season Three', 2]], 'None', [['r Truth', 4], ['One', 22], ['Two', 22], ['Three', 22], ['Four', 23], ['Five', 22], ['Six', 22], ['Seven', 22], ['Eight', 2]]], 'creature_name': ['Niklaus_Mikaelson', 'Elena_Gilbert', 'Damon_Salvatore', 'Katerina_Petrova', 'Stefan_Salvatore', 'Kol_Mikaelson'], 'show_name': ['Vampire Diaries', 'Vampire Diaries', 'Vampire Diaries', 'Vampire Diaries', 'Vampire Diaries', 'Vampire Diaries']}

# %%
pd.DataFrame(DATABASE).T.reset_index().to_csv('vampireDiariesCreatures.csv', header=True)
