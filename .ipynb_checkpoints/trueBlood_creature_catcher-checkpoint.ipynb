# %%
# Set up data collection foundation

CREATURE_NAME=[]
CREATURE_CAT=[]
SEASON_EP=[]
SHOW_NAME=[]

TABLE_COLUMNS = ['creature_name', 'creature_cat', 'season_ep', 'show_name']

DATABASE = {'creature_name':CREATURE_NAME, 'creature_cat':CREATURE_CAT, 'season_ep':SEASON_EP, 'show_name':SHOW_NAME}

TRUEBLOOD_URL = 'http://trueblood.wikia.com/wiki/Category:Species'

# %%
# Libraries

from bs4 import BeautifulSoup as soup
import pandas as pd
import re
from urllib import request

# %%
# Convert html to a more user friendly format

def soupTheLink(url):
    html = request.urlopen(url).read().decode('utf8')
    return soup(html, 'lxml')

# %%
# Scrape a list of links of the creature categories

def collectCatLinks(url):
    categoryLinks = []
    
    souped = soupTheLink(url)
    subcategories = souped.find(id='mw-subcategories')
    gallery = subcategories.find(class_='category-gallery-room1')
    for listItem in gallery.find_all(class_='category-gallery-item'):
        link = listItem.find('a', href = True)
        try:
            fullLink = link['href']
            categoryLinks.append(fullLink)
        except TypeError:
            pass
    return categoryLinks

# %%
# Jump into the list of links to the creatures based on the categories

def intoCategoryLinks(catLinks):
    currentCategory=''
    
    for mainLink in catLinks:
        currentCategory = mainLink
        print('current category: ', currentCategory)
        numPages = findNumCreaturePages(mainLink) - 1
        if numPages == 0:
            pass
        else:
            for i in range(1,numPages):
                url = mainLink  + '?page=' + str(i)
                collectCreatureLinks(url, currentCategory)

# %%
# Find the number of pages in each category

def findNumCreaturePages(url):
    souped = soupTheLink(url)
    pages = 0
    subcategories = souped.find(id='mw-pages')
    pagination = subcategories.find(class_='wikia-paginator')
    try:
        for listItem in pagination.find_all('li'):
            pages += 1
    except AttributeError:
        pass
    return pages

# %%
# Compile a list of links to each individual creature

def collectCreatureLinks(url, currentCat):
    souped = soupTheLink(url)
    subcategories = souped.find(id='mw-pages')
    for listItem in subcategories.find_all(class_='category-gallery-item'):
        link = listItem.find('a', href = True)
        try:
            fullLink = link['href']
            findCategory(currentCat)
            intoCreatureLinks(fullLink)
        except TypeError:
            pass

# %%
# Import creature category to database

def findCategory(url):
    category = str(url[41:])
    DATABASE['creature_cat'].append(category)

# %%
# Import the rest of the data to the database

def intoCreatureLinks(creatureUrl):
    print('starting intoCreatureLinks: ', creatureUrl)
    souped = soupTheLink(creatureUrl)

    #collect creature name
    name = creatureUrl[32:]
    DATABASE['creature_name'].append(name)

    #collect show name
    DATABASE['show_name'].append('True Blood')

    #collect season appearances
    currentSeason = 0
    seasonLink = ''
    body = souped.find(id='mw-content-text')
    SEASON_EP=[]
    for tables in body.find_all(class_='appearances p402_hide'):
        seasonDegree = 0
        for rows in tables.find_all('tr', limit=1):
            for seasons in rows.find_all('b', limit=1):
                season = season.get_text()
                season = season[7:-12]
                SEASON_EP.append(season)
            for row in rows.find_next_siblings('tr'):
                for episodes in row.find_all('td'):
                    seasonDegree += 1
        SEASON_EP.append(seasonDegree)

    if SEASON_EP == []:
        DATABASE['season_ep'].append('None')   
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Charlene
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Wade_Cleary
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Danielle_(werewolf)
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Elizabeth_Harris
# starting collectCreatureLinks
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Danika_Bellefleur
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Sylvie
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Bartlett_Hale
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Sarah_Compton-Harris
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Human
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Luke_McDonald
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Cindy_Marshall
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Neil_Jones
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Yvetta
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Naomi
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Caroline_Bellefleur
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Marcus_Bozeman
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/John_Dickson
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Mr._Gus
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Nancy_LeGuare
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Bud_Dearborne
# starting collectCreatureLinks
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Cooter
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Kevin_Ellis
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Kitch_Maynard
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Mavis
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Jackson_Herveaux
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Belinda
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Lisa_Fowler
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Janice_Herveaux
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Thomas_Compton
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Mae
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Timbo
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/JD_Carson
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Don_Bartolo
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Ms._Suzuki
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Theodore_Newlin
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Hugo_Ayres
# current category:  http://trueblood.wikia.com/wiki/Category:Fairies
# starting findNumCreaturePages
# starting collectCreatureLinks
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Sookie_Stackhouse
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Macklyn_Warlow
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Jason_Stackhouse
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Faerie
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Hadley_Hale
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Halfling
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Claude_Crane
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Barry_Horowitz
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Maurella
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Photokinesis
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Charlaine_Bellefleur
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Hunter_Savoy
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Queen_Mab
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Braelyn_Bellefleur
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Earl_Stackhouse
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Faerie_Elder
# starting collectCreatureLinks
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Faerie_(location)
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Danika_Bellefleur
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Leda
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Elemental_Control
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Lumiere_fruit
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Lloyd
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Faerie_Goblin
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Lilianne
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Claudia
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Hydrokinesis
# current category:  http://trueblood.wikia.com/wiki/Category:Werewolves
# starting findNumCreaturePages
# starting collectCreatureLinks
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Alcide_Herveaux
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Werewolf
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Rikki_Naylor
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Debbie_Pelt
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Emma_Garza
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Martha_Bozeman
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Danielle_(werewolf)
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Operation_Werwolf
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Marcus_Bozeman
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Jackson_Herveaux
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Cooter
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Abjuration
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/JD_Carson
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Janice_Herveaux
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Magic
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Jenny
# starting collectCreatureLinks
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Barbara_Pelt
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Were-Bitch
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Gordon_Pelt
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Kenneth
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Nate
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Hollis
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Gus
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Packmaster
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/F*ck_You_Crew
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Chuck
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/John_Flood
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Robert_Rollins
# starting findCategory
# starting intoCreatureLinks:  http://trueblood.wikia.com/wiki/Ryder
# current category:  http://trueblood.wikia.com/wiki/Category:Deities
# starting findNumCreaturePages
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e7a4e01a7237> in <module>()
#       3 categoryLinks = collectCatLinks(TRUEBLOOD_URL)
#       4 print('categoryLinks', categoryLinks)
# ----> 5 intoCategoryLinks(categoryLinks)
#
# <ipython-input-5-98dbe1c36ad2> in intoCategoryLinks(catLinks)
#       8         currentCategory = mainLink
#       9         print('current category: ', currentCategory)
# ---> 10         numPages = findNumCreaturePages(mainLink) - 1
#      11         for i in range(1,numPages):
#      12             url = mainLink  + '?page=' + str(i)
#
# <ipython-input-6-28f82b1b10f6> in findNumCreaturePages(url)
#       7     subcategories = souped.find(id='mw-pages')
#       8     pagination = subcategories.find(class_='wikia-paginator')
# ----> 9     for listItem in pagination.find_all('li'):
#      10         pages += 1
#      11     return pages
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
print('1: ', len(CREATURE_NAME), '2: ', len(CREATURE_CAT), '3: ', len(SEASON_EP), '4: ', len(SHOW_NAME), )
# Out:
# 1:  192 2:  192 3:  192 4:  192

# %%
pd.DataFrame(DATABASE).T.reset_index().to_csv('supernaturalCreatures.csv', header=True)
